# %% [markdown]
# <a href="https://colab.research.google.com/github/school1739/10G-2023/blob/student%2Ffilippov/AIGame/16Jan2023(GlassAI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# АВФТОР: ФЕЛИППОВ ЫВАН!!1

# %%
import random

# %%
# Создаём словарь стаканов
the_glasses={1:[1,1,1,2,2,2],
             2:[1,1,1,2,2,2],
             3:[1,1,1,2,2,2],
             4:[1,1,1,2,2,2],
             5:[1,1,1,2,2,2],
             6:[1,1,1,2,2,2],
             7:[1,1,1,2,2,2],
             8:[1,1,1,2,2,2],
             9:[1,1,1,2,2,2],
             10:[1,1,1,2,2,2],
             11:[1,1,1,2,2,2]}

used_glasses={}  # вывод словаря стаканов
situation = 11
ai_is_winner=False

# %%
def move(situation): # сделать ход (выбрать случайную бумажку из стакана и вернуть значение)
  detect = False
  print('Ходит ИИ:')
  if situation > 0:
    while detect == False:
      the_move = random.choice(the_glasses[situation])
      print(the_move)
      if situation - the_move >= 0:
        detect = True
    return the_move
  else:
    return(0)
def used_glass_fill(situation, move): # записать использованные стаканы и бумажки)
  used_glasses.update({situation:move})


#def human_move(choice):
#  return situation - choice

# %%
playerPoints = 0
botPoints = 0


while (playerPoints < 10 and botPoints < 10):
  situation = 11
  choice = 0 
  player_won = False
  print(f"На столе {situation} палочек")
  if ai_is_winner == False:
    while situation > 0:
      detect = False
      while detect == False:
        choice = int(input('Количество палочек, которое надо взять? (1 или 2)'))
        while choice!=1 and choice!=2:
          choice = int(input('Боже чел мамонт... 1 или 2 введи......... Клоун'))
        if situation - choice >= 0:
          detect = True
          print('sit: ' + str(situation))
        else:
          print('Чел клоун... Сток палок нет. Может свои принесёшь?')


      situation = situation - choice
      if situation == 0:
        player_won = True
      print(f"На столе {situation} палочек")
      situation = situation - move(situation)
      print(f'На столе {situation} палочек')
      print()

  if (player_won == True):
    playerPoints += 1
    print('Вау ты победил вау вау')
  else:
    botPoints += 1
    print('Бот затащил тебя в соло')
  print('Афигеть палки кончились.................')
  print(f'Счёт:\nИгрок:{playerPoints}      Бот попущенный: {botPoints}')
  print('\n\n')

print('ГЕЙМ ОВЕР ЪУЪ')
if (playerPoints == 10):
  print('Поздравляю! Победил ботика... Гордись этим всю жизнь')
elif (botPoints == 10):
  print('Чел... Тебя бот слил... Что ты делаешь в этой жизни не так?')
else:
  print(f'ТЫ СЛОМАЛ ИГРУ ИДИОТ!!! КАКИМ ОБРАЗОМ ВЫ НАБРАЛИ БОЛЬШЕ 10 ОЧКОВ!??!?!\np:{playerPoints}\nb:{botPoints}')
# Out:
# На столе 11 палочек
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 11
# На столе 9 палочек
# Ходит ИИ:
# 2
# На столе 7 палочек
#
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 7
# На столе 6 палочек
# Ходит ИИ:
# 2
# На столе 4 палочек
#
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 4
# На столе 3 палочек
# Ходит ИИ:
# 2
# На столе 1 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# Чел клоун... Сток палок нет. Может свои принесёшь?
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 1
# На столе 0 палочек
# Ходит ИИ:
# На столе 0 палочек
#
# Вау ты победил вау вау
# Афигеть палки кончились.................
# Счёт:
# Игрок:1      Бот попущенный: 0
#
#
#
# На столе 11 палочек
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 11
# На столе 9 палочек
# Ходит ИИ:
# 1
# На столе 8 палочек
#
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 8
# На столе 7 палочек
# Ходит ИИ:
# 1
# На столе 6 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 6
# На столе 4 палочек
# Ходит ИИ:
# 1
# На столе 3 палочек
#
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 3
# На столе 2 палочек
# Ходит ИИ:
# 2
# На столе 0 палочек
#
# Бот затащил тебя в соло
# Афигеть палки кончились.................
# Счёт:
# Игрок:1      Бот попущенный: 1
#
#
#
# На столе 11 палочек
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 11
# На столе 9 палочек
# Ходит ИИ:
# 2
# На столе 7 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 7
# На столе 5 палочек
# Ходит ИИ:
# 1
# На столе 4 палочек
#
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 4
# На столе 3 палочек
# Ходит ИИ:
# 1
# На столе 2 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 2
# На столе 0 палочек
# Ходит ИИ:
# На столе 0 палочек
#
# Вау ты победил вау вау
# Афигеть палки кончились.................
# Счёт:
# Игрок:2      Бот попущенный: 1
#
#
#
# На столе 11 палочек
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 11
# На столе 9 палочек
# Ходит ИИ:
# 2
# На столе 7 палочек
#
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 7
# На столе 6 палочек
# Ходит ИИ:
# 2
# На столе 4 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 4
# На столе 2 палочек
# Ходит ИИ:
# 1
# На столе 1 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# Чел клоун... Сток палок нет. Может свои принесёшь?
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 1
# На столе 0 палочек
# Ходит ИИ:
# На столе 0 палочек
#
# Вау ты победил вау вау
# Афигеть палки кончились.................
# Счёт:
# Игрок:3      Бот попущенный: 1
#
#
#
# На столе 11 палочек
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 11
# На столе 9 палочек
# Ходит ИИ:
# 1
# На столе 8 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 8
# На столе 6 палочек
# Ходит ИИ:
# 2
# На столе 4 палочек
#
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 4
# На столе 3 палочек
# Ходит ИИ:
# 1
# На столе 2 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 2
# На столе 0 палочек
# Ходит ИИ:
# На столе 0 палочек
#
# Вау ты победил вау вау
# Афигеть палки кончились.................
# Счёт:
# Игрок:4      Бот попущенный: 1
#
#
#
# На столе 11 палочек
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 11
# На столе 9 палочек
# Ходит ИИ:
# 2
# На столе 7 палочек
#
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 7
# На столе 6 палочек
# Ходит ИИ:
# 1
# На столе 5 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 5
# На столе 3 палочек
# Ходит ИИ:
# 1
# На столе 2 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 2
# На столе 0 палочек
# Ходит ИИ:
# На столе 0 палочек
#
# Вау ты победил вау вау
# Афигеть палки кончились.................
# Счёт:
# Игрок:5      Бот попущенный: 1
#
#
#
# На столе 11 палочек
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 11
# На столе 10 палочек
# Ходит ИИ:
# 1
# На столе 9 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 9
# На столе 7 палочек
# Ходит ИИ:
# 2
# На столе 5 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 5
# На столе 3 палочек
# Ходит ИИ:
# 1
# На столе 2 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 2
# На столе 0 палочек
# Ходит ИИ:
# На столе 0 палочек
#
# Вау ты победил вау вау
# Афигеть палки кончились.................
# Счёт:
# Игрок:6      Бот попущенный: 1
#
#
#
# На столе 11 палочек
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 11
# На столе 9 палочек
# Ходит ИИ:
# 1
# На столе 8 палочек
#
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 8
# На столе 7 палочек
# Ходит ИИ:
# 2
# На столе 5 палочек
#
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 5
# На столе 4 палочек
# Ходит ИИ:
# 2
# На столе 2 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 2
# На столе 0 палочек
# Ходит ИИ:
# На столе 0 палочек
#
# Вау ты победил вау вау
# Афигеть палки кончились.................
# Счёт:
# Игрок:7      Бот попущенный: 1
#
#
#
# На столе 11 палочек
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 11
# На столе 9 палочек
# Ходит ИИ:
# 2
# На столе 7 палочек
#
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 7
# На столе 6 палочек
# Ходит ИИ:
# 2
# На столе 4 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 4
# На столе 2 палочек
# Ходит ИИ:
# 1
# На столе 1 палочек
#
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 1
# На столе 0 палочек
# Ходит ИИ:
# На столе 0 палочек
#
# Вау ты победил вау вау
# Афигеть палки кончились.................
# Счёт:
# Игрок:8      Бот попущенный: 1
#
#
#
# На столе 11 палочек
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 11
# На столе 9 палочек
# Ходит ИИ:
# 1
# На столе 8 палочек
#
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 8
# На столе 7 палочек
# Ходит ИИ:
# 1
# На столе 6 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 6
# На столе 4 палочек
# Ходит ИИ:
# 2
# На столе 2 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 2
# На столе 0 палочек
# Ходит ИИ:
# На столе 0 палочек
#
# Вау ты победил вау вау
# Афигеть палки кончились.................
# Счёт:
# Игрок:9      Бот попущенный: 1
#
#
#
# На столе 11 палочек
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 11
# На столе 10 палочек
# Ходит ИИ:
# 2
# На столе 8 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 8
# На столе 6 палочек
# Ходит ИИ:
# 1
# На столе 5 палочек
#
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 5
# На столе 4 палочек
# Ходит ИИ:
# 1
# На столе 3 палочек
#
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 3
# На столе 2 палочек
# Ходит ИИ:
# 2
# На столе 0 палочек
#
# Бот затащил тебя в соло
# Афигеть палки кончились.................
# Счёт:
# Игрок:9      Бот попущенный: 2
#
#
#
# На столе 11 палочек
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 11
# На столе 9 палочек
# Ходит ИИ:
# 1
# На столе 8 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 8
# На столе 6 палочек
# Ходит ИИ:
# 2
# На столе 4 палочек
#
# Количество палочек, которое надо взять? (1 или 2)1
# sit: 4
# На столе 3 палочек
# Ходит ИИ:
# 1
# На столе 2 палочек
#
# Количество палочек, которое надо взять? (1 или 2)2
# sit: 2
# На столе 0 палочек
# Ходит ИИ:
# На столе 0 палочек
#
# Вау ты победил вау вау
# Афигеть палки кончились.................
# Счёт:
# Игрок:10      Бот попущенный: 2
#
#
#
# ГЕЙМ ОВЕР ЪУЪ
# Поздравляю! Победил ботика... Гордись этим всю жизнь
