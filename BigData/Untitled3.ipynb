# %%
import numpy as np
import pandas as pd
from datetime import datetime, date
import matplotlib.pyplot as plt

# %%
random_seed=12345

# %%
#генерация временного ряда
np.random.seed(random_seed)
the_series1=pd.Series(np.random.randn(30),
                      index=pd.date_range("2023-01-01", "2023-01-30"))
the_series1
# Out:
# 2023-01-01   -0.204708
# 2023-01-02    0.478943
# 2023-01-03   -0.519439
# 2023-01-04   -0.555730
# 2023-01-05    1.965781
# 2023-01-06    1.393406
# 2023-01-07    0.092908
# 2023-01-08    0.281746
# 2023-01-09    0.769023
# 2023-01-10    1.246435
# 2023-01-11    1.007189
# 2023-01-12   -1.296221
# 2023-01-13    0.274992
# 2023-01-14    0.228913
# 2023-01-15    1.352917
# 2023-01-16    0.886429
# 2023-01-17   -2.001637
# 2023-01-18   -0.371843
# 2023-01-19    1.669025
# 2023-01-20   -0.438570
# 2023-01-21   -0.539741
# 2023-01-22    0.476985
# 2023-01-23    3.248944
# 2023-01-24   -1.021228
# 2023-01-25   -0.577087
# 2023-01-26    0.124121
# 2023-01-27    0.302614
# 2023-01-28    0.523772
# 2023-01-29    0.000940
# 2023-01-30    1.343810
# Freq: D, dtype: float64

# %%
# отображение кумулятивной суммы
wondering=the_series1.cumsum()
wondering.plot()
# Out:
# <Axes: >

# %%
the_DataFrame1=pd.DataFrame(the_series1)
the_DataFrame1
# Out:
#                    0
# 2023-01-01 -0.204708
# 2023-01-02  0.478943
# 2023-01-03 -0.519439
# 2023-01-04 -0.555730
# 2023-01-05  1.965781
# 2023-01-06  1.393406
# 2023-01-07  0.092908
# 2023-01-08  0.281746
# 2023-01-09  0.769023
# 2023-01-10  1.246435
# 2023-01-11  1.007189
# 2023-01-12 -1.296221
# 2023-01-13  0.274992
# 2023-01-14  0.228913
# 2023-01-15  1.352917
# 2023-01-16  0.886429
# 2023-01-17 -2.001637
# 2023-01-18 -0.371843
# 2023-01-19  1.669025
# 2023-01-20 -0.438570
# 2023-01-21 -0.539741
# 2023-01-22  0.476985
# 2023-01-23  3.248944
# 2023-01-24 -1.021228
# 2023-01-25 -0.577087
# 2023-01-26  0.124121
# 2023-01-27  0.302614
# 2023-01-28  0.523772
# 2023-01-29  0.000940
# 2023-01-30  1.343810

# %%
the_DataFrame.plot()
# Out:
# <Axes: >

# %%
the_series1.plot()
# Out:
# <Axes: >

# %%
the_DataFrame1=pd.DataFrame(np.random.randn(30,3),
                            columns=[list("ABC")])
the_DataFrame1
# Out:
#            A         B         C
# 0  -0.713544 -0.831154 -2.370232
# 1  -1.860761 -0.860757  0.560145
# 2  -1.265934  0.119827 -1.063512
# 3   0.332883 -2.359419 -0.199543
# 4  -1.541996 -0.970736 -1.307030
# 5   0.286350  0.377984 -0.753887
# 6   0.331286  1.349742  0.069877
# 7   0.246674 -0.011862  1.004812
# 8   1.327195 -0.919262 -1.549106
# 9   0.022185  0.758363 -0.660524
# 10  0.862580 -0.010032  0.050009
# 11  0.670216  0.852965 -0.955869
# 12 -0.023493 -2.304234 -0.652469
# 13 -1.218302 -1.332610  1.074623
# 14  0.723642  0.690002  1.001543
# 15 -0.503087 -0.622274 -0.921169
# 16 -0.726213  0.222896  0.051316
# 17 -1.157719  0.816707  0.433610
# 18  1.010737  1.824875 -0.997518
# 19  0.850591 -0.131578  0.912414
# 20  0.188211  2.169461 -0.114928
# 21  2.003697  0.029610  0.795253
# 22  0.118110 -0.748532  0.584970
# 23  0.152677 -1.565657 -0.562540
# 24 -0.032664 -0.929006 -0.482573
# 25 -0.036264  1.095390  0.980928
# 26 -0.589488  1.581700 -0.528735
# ...

# %%
the_DataFrame1.plot()
# Out:
# <Axes: >

# %%
set3=np.arange(0., 3., 2.0)
frame3=pd.DataFrame({0: set3,
                     1: set3**2,
                     2: set3**3.5,
                     3: set3**5})
frame3
# Out:
#      0    1          2     3
# 0  0.0  0.0   0.000000   0.0
# 1  2.0  4.0  11.313708  32.0

# %%
frame3=styles.plot(style=["r-", "b--", "g.", "y.-"])
